# %%
import pandas as pd

df = pd.read_csv("data_vancouver_copy.csv",encoding = "ISO-8859-1")

headers = ['address', 'price', 'Bedrooms', 'Bath', 'Lot Size', 'Property Age',
       'Gross Taxes for 2020', 'Area', 'Sub-Area/Community', 'Property Type',
       'Title', 'Style', 'Heating Type', 'Depth', 'Frontage']
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-43aacd8222f4> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("data_vancouver_copy.csv",encoding = "ISO-8859-1")
#       4
#       5 headers = ['address', 'price', 'Bedrooms', 'Bath', 'Lot Size', 'Property Age','Gross Taxes for 2020', 'Area', 'Sub-Area/Community', 'Property Type','Title', 'Style', 'Heating Type', 'Depth', 'Frontage']
#
# ...

# %%
#### Read Headers
# df.columns

## Read each Column
# print(df[['address', 'price', 'Lot Size']])

## Read Each Row
# print(df.iloc[0:4])
# for index, row in df.iterrows():
#     print(index,row['price'])
# df.loc[df['Property Type'] == 'House']

## Read a specific location (R,C)
print(df.iloc[2,2])
df.sort_values(['price'],ascending=[0])
# Out:
# 4.0
#                        address       price  Bedrooms  Bath  \
# 343  1806 128 W Cordova Street    $999,999       2.0   2.0
# 841      2396 Cambridge Street    $999,998       3.0   3.0
# 726      1304 1159 Main Street    $999,990       3.0   2.0
# 659      4525 Clarendon Street    $999,900       2.0   2.0
# 127    A203 4908 Cambie Street    $999,000       2.0   2.0
# ..                         ...         ...       ...   ...
# 586    501 1003 Pacific Street  $1,029,900       2.0   2.0
# 583    501 1003 Pacific Street  $1,029,900       2.0   2.0
# 323    1302 1133 Hornby Street  $1,020,000       2.0   2.0
# 221                        NaN         NaN       NaN   NaN
# 264                        NaN         NaN       NaN   NaN
#
#                        Lot Size                Property Age  \
# 343  Built in 2009 (11 yrs old)                      $3,012
# 841      34 ft x 122 ft (0 ft²)  Built in 2002 (18 yrs old)
# 726  Built in 1992 (28 yrs old)                      $3,075
# ...

# %%
# check item from price is null and drop NA
df[df['price'].isnull()]
df = df.dropna(subset=['price'])
# convert string to integer
df['price'] = df['price'].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
df = pd.read_csv("data_vancouver_copy.csv",encoding = "ISO-8859-1")

df['Gross Taxes for 2020'] = df['Gross Taxes for 2020'].replace('[\$\,\.]', '', regex=True)

for i,x in enumerate(df['Gross Taxes for 2020']):
    try:
        df['Gross Taxes for 2020'][i] = float(x)
    except:
        df['Gross Taxes for 2020'][i] = None
# Out:
# <ipython-input-216-5ecbbe4b3f69>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gross Taxes for 2020'][i] = float(x)
# <ipython-input-216-5ecbbe4b3f69>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gross Taxes for 2020'][i] = None

# %%
# df['Total'] = df.loc[:,['price','Gross Taxes for 2020']].sum(axis=1)
# df['Total']

# %%
# remove all rows that are not houses
for i,t in enumerate(df['Property Type']):
    if t not in ['House']:
        df = df.drop(i,axis=0)

# %%
df.describe()
# Out:
#          Bedrooms        Bath  Built in 1999 (21 yrs old)  $1,568  $431  \
# count  457.000000  457.000000                         0.0     0.0   0.0
# mean     5.271335    4.247265                         NaN     NaN   NaN
# std      1.689982    2.090632                         NaN     NaN   NaN
# min      0.000000    0.000000                         NaN     NaN   NaN
# 25%      4.000000    3.000000                         NaN     NaN   NaN
# 50%      5.000000    4.000000                         NaN     NaN   NaN
# 75%      6.000000    6.000000                         NaN     NaN   NaN
# max     12.000000   12.000000                         NaN     NaN   NaN
#
#        Vancouver West  Kitsilano  Apt/Condo  Freehold Strata  \
# count             0.0        0.0        0.0              0.0
# mean              NaN        NaN        NaN              NaN
# std               NaN        NaN        NaN              NaN
# min               NaN        NaN        NaN              NaN
# ...
