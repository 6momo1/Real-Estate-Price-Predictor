# %%
import pandas as pd

df = pd.read_csv("data_vancouver_copy.csv",encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#                       address       price  Bedrooms  Bath  \
# 0  232 2565 W Broadway Avenue  $1,065,000       2.0   3.0
# 1    203 2160 Cornwall Avenue    $948,000       2.0   2.0
# 2          2781 W 15th Avenue  $2,470,000       4.0   3.0
# 3          2289 W 12th Avenue  $1,299,000       2.0   2.0
# 4         1768 Cypress Street  $2,190,000       3.0   3.0
#
#                      Lot Size                Property Age  \
# 0  Built in 1995 (25 yrs old)                      $2,823
# 1  Built in 1992 (28 yrs old)                      $2,402
# 2                    4026 ft²  Built in 1929 (91 yrs old)
# 3  Built in 1998 (22 yrs old)                      $2,879
# 4  Built in 2022 (-2 yrs old)                        $999
#
#   Gross Taxes for 2020            Area Sub-Area/Community Property Type  ...  \
# 0                 $481  Vancouver West          Kitsilano     Townhouse  ...
# 1                 $508  Vancouver West          Kitsilano     Apt/Condo  ...
# ...

# %%
df.columns
# Out:
# Index(['address', 'price', 'Bedrooms', 'Bath', 'Lot Size', 'Property Age',
#        'Gross Taxes for 2020', 'Area', 'Sub-Area/Community', 'Property Type',
#        'Title', 'Style', 'Heating Type', 'Depth', 'Frontage', 'Listing ID',
#        'Primary Agent', 'Primary Broker', 'Secondary Agent',
#        'Secondary Broker', 'Days on REW', 'Features', 'Amenities',
#        'Appliances', 'Fireplaces', 'Air Conditioner405 2688 Vine Street',
#        '$589,900', '1', '1.1', 'Built in 1999 (21 yrs old)', '$1,568', '$431',
#        'Vancouver West', 'Kitsilano', 'Apt/Condo', 'Freehold Strata',
#        'Inside Unit,Upper Unit', 'R2521594', 'Doug Fielding PREC*',
#        'Stonehaus Realty Corp.', '23 Days on REW',
#        'Recreation Nearby, Shopping Nearby',
#        'Washer/Dryer/Fridge/Stove/Dishwasher',
#        'Elevator, In Suite Laundry, Recreation Center', '1.2'],
#       dtype='object')
